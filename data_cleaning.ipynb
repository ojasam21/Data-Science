# %%
import json

# %%
import json

def clean_data(data2):
    # Remove users with missing names
    data2["users"] = [user for user in data2["users"] if user["name"].strip()]
    
    # Remove duplicate friends
    for user in data2["users"]:
        user["friends"] = list(set(user["friends"]))
    
    # Remove inactive users
    data2["users"] = [user for user in data["users"] if user["friends"] or user["liked_pages"]]
    
    # Remove duplicate pages
    unique_pages = {}
    for page in data2["pages"]:
        unique_pages[page["id"]] = page
    data2["pages"] = list(unique_pages.values())
    
    return data

# Load, clean, and display the cleaned data
data2 = json.load(open("data.json"))
data2 = clean_data(data)
json.dump(data2, open("cleaned_codebook_data.json", "w"), indent=4)
print("Data cleaned successfully!")
# Out:
# Data cleaned successfully!
