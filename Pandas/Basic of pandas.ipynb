# %%
import pandas as pd

# %%
#series is like list with label's
s = pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s2 = pd.Series([99,98,97,96,95,94,93], index = ["ojas" , "Aneesh" , "ayush" , "rahul" , "Piyush" , "apurva" , "sai"])

# %%
s2
# Out:
# ojas      99
# Aneesh    98
# ayush     97
# rahul     96
# Piyush    95
# apurva    94
# sai       93
# dtype: int64

# %%
s2["Aneesh"]
# Out:
# np.int64(98)

# %%
#data frame is 2d it is like a dictonary of a series
data = {"name" : ["Alice" , "Bob" , "Charlie"],
        "age" : [25, 30, 35],
        "city": ["Delhi", "Mumbai", "Banglore"]
       }
df = pd.DataFrame(data)
print(df)
# Out:
#       name  age      city
# 0    Alice   25     Delhi
# 1      Bob   30    Mumbai
# 2  Charlie   35  Banglore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)
